# %%
import re
import nltk
import pandas as pd
from collections import Counter
from pymorphy3 import MorphAnalyzer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords

# %%
morph = MorphAnalyzer()
stemmer = SnowballStemmer("russian")
stop_words = set(stopwords.words("russian"))

# %%
text = """
ГЛАВА I
КЛАССОВОЕ ОБЩЕСТВО И ГОСУДАРСТВО
1. ГОСУДАРСТВО - ПРОДУКТ НЕПРИМИРИМОСТИ КЛАССОВЫХ ПРОТИВОРЕЧИЙ
С учением Маркса происходит теперь то, что не раз бывало в истории с учениями революционных мыслителей и вождей угнетенных классов в их борьбе за освобождение. 
Угнетающие классы при жизни великих революционеров платили им постоянными преследованиями, встречали их учение самой дикой злобой, самой бешеной ненавистью, самым бесшабашным походом лжи и клеветы. 
После их смерти делаются попытки превратить их в безвредные иконы, так сказать, канонизировать их, предоставить известную славу их имени для "утешения" угнетенных классов и для одурачения их, 
выхолащивая содержание революционного учения, притупляя его революционное острие, опошляя его. На такой "обработке" марксизма сходятся сейчас буржуазия и оппортунисты внутри рабочего движения. 
Забывают, оттирают, искажают революционную сторону учения, его революционную душу. Выдвигают на первый план, прославляют то, что приемлемо или что кажется приемлемым для буржуазии. 
Все социал-шовинисты нынче "марксисты", не шутите! И все чаще немецкие буржуазные ученые, вчерашние специалисты по истреблению марксизма, говорят о "национально-немецком" Марксе, 
который будто бы воспитал так великолепно организованные для ведения грабительской войны союзы рабочих!
"""

# %%
def tokenize_by_letters(text: str) -> list[str]:
    return re.findall(r'[а-яё]', text.lower())

def tokenize_by_words(text: str) -> list[str]:
    words = re.findall(r'[а-яё]+', text.lower())  # Извлекаем только слова
    return [word for word in words if word not in stop_words]

def lemmatize(tokens: list[str]) -> list[str]:
    return [morph.parse(word)[0].normal_form for word in tokens]

def stem(tokens: list[str]) -> list[str]:
    return [stemmer.stem(word) for word in tokens]

def vectorize_by_letters(tokens: list[str]) -> pd.DataFrame:
    letter_counts = Counter(tokens)
    df = pd.DataFrame([letter_counts], columns=sorted(letter_counts.keys())).fillna(0).astype(int)
    return df

# %%
letter_tokens = tokenize_by_letters(text)
word_tokens = tokenize_by_words(text)
lemmatized_text = lemmatize(word_tokens)
stemmed_text = stem(word_tokens)
letter_vectorized_text = vectorize_by_letters(letter_tokens)

# %%
print("\nТокенизированный текст:", letter_tokens)
print("\nЛемматизированный текст:", lemmatized_text)
print("\nСтемминг текста:", stemmed_text)
print("\nВекторизация:\n", letter_vectorized_text)
# Out:
# Токенизированный текст: ['г', 'л', 'а', 'в', 'а', 'к', 'л', 'а', 'с', 'с', 'о', 'в', 'о', 'е', 'о', 'б', 'щ', 'е', 'с', 'т', 'в', 'о', 'и', 'г', 'о', 'с', 'у', 'д', 'а', 'р', 'с', 'т', 'в', 'о', 'г', 'о', 'с', 'у', 'д', 'а', 'р', 'с', 'т', 'в', 'о', 'п', 'р', 'о', 'д', 'у', 'к', 'т', 'н', 'е', 'п', 'р', 'и', 'м', 'и', 'р', 'и', 'м', 'о', 'с', 'т', 'и', 'к', 'л', 'а', 'с', 'с', 'о', 'в', 'ы', 'х', 'п', 'р', 'о', 'т', 'и', 'в', 'о', 'р', 'е', 'ч', 'и', 'й', 'с', 'у', 'ч', 'е', 'н', 'и', 'е', 'м', 'м', 'а', 'р', 'к', 'с', 'а', 'п', 'р', 'о', 'и', 'с', 'х', 'о', 'д', 'и', 'т', 'т', 'е', 'п', 'е', 'р', 'ь', 'т', 'о', 'ч', 'т', 'о', 'н', 'е', 'р', 'а', 'з', 'б', 'ы', 'в', 'а', 'л', 'о', 'в', 'и', 'с', 'т', 'о', 'р', 'и', 'и', 'с', 'у', 'ч', 'е', 'н', 'и', 'я', 'м', 'и', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'н', 'ы', 'х', 'м', 'ы', 'с', 'л', 'и', 'т', 'е', 'л', 'е', 'й', 'и', 'в', 'о', 'ж', 'д', 'е', 'й', 'у', 'г', 'н', 'е', 'т', 'е', 'н', 'н', 'ы', 'х', 'к', 'л', 'а', 'с', 'с', 'о', 'в', 'в', 'и', 'х', 'б', 'о', 'р', 'ь', 'б', 'е', 'з', 'а', 'о', 'с', 'в', 'о', 'б', 'о', 'ж', 'д', 'е', 'н', 'и', 'е', 'у', 'г', 'н', 'е', 'т', 'а', 'ю', 'щ', 'и', 'е', 'к', 'л', 'а', 'с', 'с', 'ы', 'п', 'р', 'и', 'ж', 'и', 'з', 'н', 'и', 'в', 'е', 'л', 'и', 'к', 'и', 'х', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'е', 'р', 'о', 'в', 'п', 'л', 'а', 'т', 'и', 'л', 'и', 'и', 'м', 'п', 'о', 'с', 'т', 'о', 'я', 'н', 'н', 'ы', 'м', 'и', 'п', 'р', 'е', 'с', 'л', 'е', 'д', 'о', 'в', 'а', 'н', 'и', 'я', 'м', 'и', 'в', 'с', 'т', 'р', 'е', 'ч', 'а', 'л', 'и', 'и', 'х', 'у', 'ч', 'е', 'н', 'и', 'е', 'с', 'а', 'м', 'о', 'й', 'д', 'и', 'к', 'о', 'й', 'з', 'л', 'о', 'б', 'о', 'й', 'с', 'а', 'м', 'о', 'й', 'б', 'е', 'ш', 'е', 'н', 'о', 'й', 'н', 'е', 'н', 'а', 'в', 'и', 'с', 'т', 'ь', 'ю', 'с', 'а', 'м', 'ы', 'м', 'б', 'е', 'с', 'ш', 'а', 'б', 'а', 'ш', 'н', 'ы', 'м', 'п', 'о', 'х', 'о', 'д', 'о', 'м', 'л', 'ж', 'и', 'и', 'к', 'л', 'е', 'в', 'е', 'т', 'ы', 'п', 'о', 'с', 'л', 'е', 'и', 'х', 'с', 'м', 'е', 'р', 'т', 'и', 'д', 'е', 'л', 'а', 'ю', 'т', 'с', 'я', 'п', 'о', 'п', 'ы', 'т', 'к', 'и', 'п', 'р', 'е', 'в', 'р', 'а', 'т', 'и', 'т', 'ь', 'и', 'х', 'в', 'б', 'е', 'з', 'в', 'р', 'е', 'д', 'н', 'ы', 'е', 'и', 'к', 'о', 'н', 'ы', 'т', 'а', 'к', 'с', 'к', 'а', 'з', 'а', 'т', 'ь', 'к', 'а', 'н', 'о', 'н', 'и', 'з', 'и', 'р', 'о', 'в', 'а', 'т', 'ь', 'и', 'х', 'п', 'р', 'е', 'д', 'о', 'с', 'т', 'а', 'в', 'и', 'т', 'ь', 'и', 'з', 'в', 'е', 'с', 'т', 'н', 'у', 'ю', 'с', 'л', 'а', 'в', 'у', 'и', 'х', 'и', 'м', 'е', 'н', 'и', 'д', 'л', 'я', 'у', 'т', 'е', 'ш', 'е', 'н', 'и', 'я', 'у', 'г', 'н', 'е', 'т', 'е', 'н', 'н', 'ы', 'х', 'к', 'л', 'а', 'с', 'с', 'о', 'в', 'и', 'д', 'л', 'я', 'о', 'д', 'у', 'р', 'а', 'ч', 'е', 'н', 'и', 'я', 'и', 'х', 'в', 'ы', 'х', 'о', 'л', 'а', 'щ', 'и', 'в', 'а', 'я', 'с', 'о', 'д', 'е', 'р', 'ж', 'а', 'н', 'и', 'е', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'н', 'о', 'г', 'о', 'у', 'ч', 'е', 'н', 'и', 'я', 'п', 'р', 'и', 'т', 'у', 'п', 'л', 'я', 'я', 'е', 'г', 'о', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'н', 'о', 'е', 'о', 'с', 'т', 'р', 'и', 'е', 'о', 'п', 'о', 'ш', 'л', 'я', 'я', 'е', 'г', 'о', 'н', 'а', 'т', 'а', 'к', 'о', 'й', 'о', 'б', 'р', 'а', 'б', 'о', 'т', 'к', 'е', 'м', 'а', 'р', 'к', 'с', 'и', 'з', 'м', 'а', 'с', 'х', 'о', 'д', 'я', 'т', 'с', 'я', 'с', 'е', 'й', 'ч', 'а', 'с', 'б', 'у', 'р', 'ж', 'у', 'а', 'з', 'и', 'я', 'и', 'о', 'п', 'п', 'о', 'р', 'т', 'у', 'н', 'и', 'с', 'т', 'ы', 'в', 'н', 'у', 'т', 'р', 'и', 'р', 'а', 'б', 'о', 'ч', 'е', 'г', 'о', 'д', 'в', 'и', 'ж', 'е', 'н', 'и', 'я', 'з', 'а', 'б', 'ы', 'в', 'а', 'ю', 'т', 'о', 'т', 'т', 'и', 'р', 'а', 'ю', 'т', 'и', 'с', 'к', 'а', 'ж', 'а', 'ю', 'т', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'н', 'у', 'ю', 'с', 'т', 'о', 'р', 'о', 'н', 'у', 'у', 'ч', 'е', 'н', 'и', 'я', 'е', 'г', 'о', 'р', 'е', 'в', 'о', 'л', 'ю', 'ц', 'и', 'о', 'н', 'н', 'у', 'ю', 'д', 'у', 'ш', 'у', 'в', 'ы', 'д', 'в', 'и', 'г', 'а', 'ю', 'т', 'н', 'а', 'п',  ...
#
# Лемматизированный текст: ['глава', 'классовый', 'общество', 'государство', 'государство', 'продукт', 'непримиримость', 'классовый', 'противоречие', 'учение', 'маркс', 'происходить', 'бывало', 'история', 'учение', 'революционный', 'мыслитель', 'вождь', 'угнести', 'класс', 'борьба', 'освобождение', 'угнетать', 'класс', 'жизнь', 'великий', 'революционер', 'платить', 'постоянный', 'преследование', 'встречать', 'учение', 'сам', 'дикий', 'злоба', 'сам', 'бешеный', 'ненависть', 'самый', 'бесшабашный', 'поход', 'ложь', 'клевета', 'смерть', 'делаться', 'попытка', 'превратить', 'безвредный', 'икона', 'сказать', 'канонизировать', 'предоставить', 'известный', 'слава', 'имя', 'утешение', 'угнести', 'класс', 'одурачение', 'выхолащивать', 'содержание', 'революционный', 'учение', 'притуплять', 'революционный', 'остриё', 'опошлять', 'обработка', 'марксизм', 'сходиться', 'буржуазия', 'оппортунист', 'внутри', 'рабочий', 'движение', 'забывать', 'оттирать', 'искажать', 'революционный', 'сторона', 'учение', 'революционный', 'душа', 'выдвигать', 'первый', 'план', 'прославлять', 'приемлемый', 'казаться', 'приемлемый', 'буржуазия', 'социала', 'шовинист', 'нынче', 'марксист', 'шутить', 'частый', 'немецкий', 'буржуазный', 'учёный', 'вчерашний', 'специалист', 'истребление', 'марксизм', 'говорить', 'национальный', 'немецкий', 'маркс', 'который', 'воспитать', 'великолепно', 'организовать', 'ведение', 'грабительский', 'война', 'союз', 'рабочий']
#
# Стемминг текста: ['глав', 'классов', 'обществ', 'государств', 'государств', 'продукт', 'непримирим', 'классов', 'противореч', 'учен', 'маркс', 'происход', 'быва', 'истор', 'учен', 'революцион', 'мыслител', 'вожд', 'угнетен', 'класс', 'борьб', 'освобожден', 'угнета', 'класс', 'жизн', 'велик', 'революционер', 'плат', 'постоя', 'преследован', 'встреча', 'учен', 'сам', 'дик', 'злоб', 'сам', 'бешен', 'ненавист', 'сам', 'бесшабашн', 'поход', 'лжи', 'клевет', 'смерт', 'дела', 'попытк', 'преврат', 'безвредн', 'икон', 'сказа', 'канонизирова', 'предостав', 'известн', 'слав', 'имен', 'утешен', 'угнетен', 'класс', 'одурачен', 'выхолащив', 'содержан', 'революцион', 'учен', 'притупл', 'революцион', 'остр', 'опошл', 'обработк', 'марксизм', 'сход', 'буржуаз', 'оппортунист', 'внутр', 'рабоч', 'движен', 'забыва', 'оттира', 'искажа', 'революцион', 'сторон', 'учен', 'революцион', 'душ', 'выдвига', 'перв', 'план', 'прославля', 'приемлем', 'кажет', 'приемлем', 'буржуаз', 'социа', 'шовинист', 'нынч', 'марксист', 'шут', 'чащ', 'немецк', 'буржуазн', 'учен', 'вчерашн', 'специалист', 'истреблен', 'марксизм', 'говор', 'национальн', 'немецк', 'маркс', 'котор', 'воспита', 'великолепн', 'организова', 'веден', 'грабительск', 'войн', 'союз', 'рабоч']
#
# Векторизация:
#      а   б   в   г   д   е   ж   з    и   й  ...   у   х   ц   ч  ш  щ   ы  ь  \
# 0  73  22  52  15  24  99  11  16  104  14  ...  32  17  11  18  9  4  31  9
#
#     ю   я
# 0  19  25
#
# [1 rows x 29 columns]
